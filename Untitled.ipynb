# %%
mapdata = [
		['us-ma', 32.8],
		['us-wa', 14.8],
		['us-ca', 12.8],
		['us-or', 12.6],
		['us-wi', 19.2],
		['us-me', 27.9],
		['us-mi', 26.6],
		['us-nv', 21.2],
		['us-nm', 26.7],
		['us-co', 16.8],
		['us-wy', 11.1],
		['us-ks', 12.4],
		['us-ne', 21.2],
		['us-ok', 18.4],
		['us-mo', 27.5],
		['us-il', 21.3],
		['us-in', 25.6],
		['us-vt', 26.6],
		['us-ar', 15.7],
		['us-tx', 10.4],
		['us-ri', 30.1 ],
		['us-al', 16.6],
		['us-ms', 10.8],
		['us-nc', 22.4],
		['us-va', 17.1],
		['us-ia', 9.6],
		['us-md', 37.2],
		['us-de', 43.8],
		['us-pa', 36.1],
		['us-nj', 36.1],
		['us-ny', 18.4],
		['us-id', 14.6],
		['us-sd', 6.9],
		['us-ct', 30.7],
		['us-nh', 35.8],
		['us-ky', 30.9],
		['us-oh', 35.9],
		['us-tn', 27.5],
		['us-wv', 51.5],
		['us-dc', 'N/A'],
		['us-la', 25.4],
		['us-fl', 22.8],
		['us-ga', 13.2],
		['us-sc', 22.6],
		['us-mn', 11.5],
		['us-mt', 12.2],
		['us-nd', 10.2],
		['us-az', 23.8],
		['us-ut', 21.2],
		['us-hi', 14.3],
		['us-ak', 14.6]
	];

# %%
mapdatadata
# Out:
# [['us-ma', 32.8],
#  ['us-wa', 14.8],
#  ['us-ca', 12.8],
#  ['us-or', 12.6],
#  ['us-wi', 19.2],
#  ['us-me', 27.9],
#  ['us-mi', 26.6],
#  ['us-nv', 21.2],
#  ['us-nm', 26.7],
#  ['us-co', 16.8],
#  ['us-wy', 11.1],
#  ['us-ks', 12.4],
#  ['us-ne', 21.2],
#  ['us-ok', 18.4],
#  ['us-mo', 27.5],
#  ['us-il', 21.3],
#  ['us-in', 25.6],
#  ['us-vt', 26.6],
#  ['us-ar', 15.7],
#  ['us-tx', 10.4],
#  ['us-ri', 30.1],
#  ['us-al', 16.6],
#  ['us-ms', 10.8],
#  ['us-nc', 22.4],
#  ['us-va', 17.1],
#  ['us-ia', 9.6],
#  ['us-md', 37.2],
#  ['us-de', 43.8],
#  ['us-pa', 36.1],
#  ['us-nj', 36.1],
#  ['us-ny', 18.4],
#  ['us-id', 14.6],
#  ['us-sd', 6.9],
#  ['us-ct', 30.7],
#  ['us-nh', 35.8],
#  ['us-ky', 30.9],
#  ['us-oh', 35.9],
#  ['us-tn', 27.5],
#  ['us-wv', 51.5],
#  ['us-dc', 'N/A'],
#  ['us-la', 25.4],
#  ['us-fl', 22.8],
#  ['us-ga', 13.2],
#  ['us-sc', 22.6],
#  ['us-mn', 11.5],
#  ['us-mt', 12.2],
#  ['us-nd', 10.2],
#  ['us-az', 23.8],
#  ['us-ut', 21.2],
#  ['us-hi', 14.3],
# ...

# %%
new_data = []
for point in mapdata:
    new_data.append({'z': point[1], 'name': point[0]})

# %%
new_data
# Out:
# [{'z': 32.8, 'name': 'us-ma'},
#  {'z': 14.8, 'name': 'us-wa'},
#  {'z': 12.8, 'name': 'us-ca'},
#  {'z': 12.6, 'name': 'us-or'},
#  {'z': 19.2, 'name': 'us-wi'},
#  {'z': 27.9, 'name': 'us-me'},
#  {'z': 26.6, 'name': 'us-mi'},
#  {'z': 21.2, 'name': 'us-nv'},
#  {'z': 26.7, 'name': 'us-nm'},
#  {'z': 16.8, 'name': 'us-co'},
#  {'z': 11.1, 'name': 'us-wy'},
#  {'z': 12.4, 'name': 'us-ks'},
#  {'z': 21.2, 'name': 'us-ne'},
#  {'z': 18.4, 'name': 'us-ok'},
#  {'z': 27.5, 'name': 'us-mo'},
#  {'z': 21.3, 'name': 'us-il'},
#  {'z': 25.6, 'name': 'us-in'},
#  {'z': 26.6, 'name': 'us-vt'},
#  {'z': 15.7, 'name': 'us-ar'},
#  {'z': 10.4, 'name': 'us-tx'},
#  {'z': 30.1, 'name': 'us-ri'},
#  {'z': 16.6, 'name': 'us-al'},
#  {'z': 10.8, 'name': 'us-ms'},
#  {'z': 22.4, 'name': 'us-nc'},
#  {'z': 17.1, 'name': 'us-va'},
#  {'z': 9.6, 'name': 'us-ia'},
#  {'z': 37.2, 'name': 'us-md'},
#  {'z': 43.8, 'name': 'us-de'},
#  {'z': 36.1, 'name': 'us-pa'},
#  {'z': 36.1, 'name': 'us-nj'},
# ...
